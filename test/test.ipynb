# %%
import re
import random
import statistics

# %%
# https://wordlegame.org/

# %%
def do_black(words_now, l, input_word, p):
    w=[]
    if l in input_word[:p]+input_word[p+1:]:
        w = words_now
    else:
        for i in words_now:
            if re.search(l, i) is None:
                w.append(i)        
    return w

def do_yellow(words_now, l, input_word, p):
    w=[]
    for i in words_now:
        if re.search(l, i) is not None and i[p]!=l:
            w.append(i)
    return w

def do_green(words_now, l, input_word, p):
    w=[]
    for i in words_now:
        if i[p] == l:
            w.append(i)
    return w

def do_guess(words_now, input_word, input_color):
    for i,j in enumerate(zip(input_word, input_color)):
        if j[1] == 'b':
            words_now = do_black(words_now, j[0], input_word, i)
        if j[1] == 'y':
            words_now = do_yellow(words_now, j[0], input_word, i)
        if j[1] == 'g':
            words_now = do_green(words_now, j[0], input_word, i)
    if input_color != 'ggggg' and input_word in words_now:
        words_now.remove(input_word)
    input_word = words_now[0]
    return words_now, input_word

def pass_word(words_now):
    words_now = words_now[1:]
    input_word = words_now[0]
    return words_now, input_word

def read_words(WORD_LENGTH):
    words = []
    with open("data/words.txt") as f:
        next(f)
        for line in f:
            words.append(line.split()[0])
    # all_words = [i.lower() for i in words if len(i)==WORD_LENGTH and len(set(i))==WORD_LENGTH]
    all_words = [i.lower() for i in words if len(i)==WORD_LENGTH]
    return all_words

def main():
    WORD_LENGTH = 5
    guess_times = 1
    all_words = read_words(WORD_LENGTH)
    input_word = all_words[0]
    print(f"#{guess_times} Guess Word is: \x1b[6;30;42m{input_word}\x1b[0m")
    while True:
        guess_times += 1
        input_color = input("Please enter a color string (5 letters) \n(b is gray; y is yellow; g is green): ")
        if input_color == 'no':
            all_words, input_word = pass_word(all_words)
            print(f"\n#{guess_times} Guess Word is: \x1b[6;30;42m{input_word}\x1b[0m")
            guess_times -= 1
            continue
        elif len(input_color) != WORD_LENGTH or any(x not in ['b', 'y', 'g'] for x in input_color):
            print("Sorry, your input should be 'no'(not valid word) or '5 byg string'(the color of output)")
            print("(b is gray; y is yellow; g is green)\n")
            continue
        all_words, input_word = do_guess(all_words, input_word, input_color)
        print(f"\n#{guess_times} Guess Word is: \x1b[6;30;42m{input_word}\x1b[0m")

# %%
words = []
feq=0
with open("data/words.txt") as f:
    next(f)
    for line in f:
        feq+=int(line.split()[1])
#         words.append(line.split()[0])
#         feq.append(int(line.split()[1]))
# all_words = [i.lower() for i in words if len(i)==WORD_LENGTH and len(set(i))==WORD_LENGTH]
# for i,j in zip(words, feq):
#         words.append(i.lower())

# %%
with open("data/words.txt") as f, open("data/words2.txt","w") as f2:
    next(f)
    f2.write(f"word\tfequency\n")
    for line in f:
        f2.write(f'{line.split()[0]}\t{int(line.split()[1])/feq}\n')

# %%
def read_words2(WORD_LENGTH):
    words = []
    feq=[]
    with open("data/words.txt") as f:
        next(f)
        for line in f:
            words.append(line.split()[0])
            feq.append(int(line.split()[1]))
    # all_words = [i.lower() for i in words if len(i)==WORD_LENGTH and len(set(i))==WORD_LENGTH]
    for i,j in zip(words, feq):
        if len(i)==WORD_LENGTH:
            words.append(i.lower())
            feq.append(j)
    
    p = [i/sum(feq) for i in feq]
    return words, p

def read_words2(WORD_LENGTH):
    words = []
    p=[]
    with open("data/words2.txt") as f:
        next(f)
        for line in f:
            a = line.split()
            if len(a[0]) == WORD_LENGTH:
                words.append(a[0].lower())
                p.append(float(a[1]))    
    return words, p

# %%
def report_color(final_word, test_word):
    color=[0,0,0,0,0]
    for i,l in enumerate(test_word):
        if final_word[i]==l:
            color[i]='g'
        else:
            if l in final_word[:i]+final_word[i+1:]:
                if final_word.count(l)<=test_word[:i].count(l):
                    color[i]='b'
                else:
                    color[i]='y'
            else:
                color[i]='b'
    return ''.join(color)

# %%
WORD_LENGTH=5
words,p = read_words2(WORD_LENGTH)

# %%
statistics.mean(num_steps)
# Out:
# 3.29

# %%
num_steps=[]
for i in range(100):
    all_words = words.copy()
    all_p = p.copy()
    steps=1
    final_word = random.choices(all_words,all_p)[0]
    
    input_word = all_words[0]
    print(final_word, input_word)
    while input_word != final_word:
        input_color = report_color(final_word, input_word)
        all_words, input_word = do_guess(all_words, input_word, input_color)
        steps+=1
    print(f"{final_word}: {steps}")
    num_steps.append(steps)
# Out:
# threw there
# threw: 3
# where there
# where: 2
# jerry there
# jerry: 3
# their there
# their: 2
# there there
# there: 1
# right there
# right: 2
# index there
# index: 5
# hands there
# hands: 4
# every there
# every: 2
# group there
# group: 5
# under there
# under: 3
# rocky there
# rocky: 5
# after there
# after: 2
# guess there
# guess: 2
# court there
# court: 3
# right there
# right: 2
# right there
# right: 2
# there there
# there: 1
# which there
# which: 2
# added there
# added: 4
# sunup there
# sunup: 5
# looks there
# looks: 4
# handy there
# handy: 4
# sound there
# sound: 5
# grass there
# grass: 5
# these there
# these: 2
# hello there
# hello: 2
# speak there
# speak: 4
# death there
# death: 2
# spear there
# spear: 5
# plays there
# plays: 4
# miami there
# miami: 5
# there there
# there: 1
# would there
# would: 3
# dandy there
# dandy: 4
# there there
# there: 1
# right there
# right: 2
# again there
# again: 3
# where there
# where: 2
# night there
# night: 2
# smoke there
# smoke: 3
# every there
# every: 2
# doubt there
# doubt: 3
# great there
# great: 2
# gonna there
# gonna: 3
# place there
# place: 4
# mouse there
# mouse: 4
# doing there
# doing: 3
# funky there
# funky: 5
# sorry there
# sorry: 2
# major there
# major: 5
# worry there
# worry: 3
# notes there
# notes: 4
# thing there
# thing: 3
# robin there
# robin: 5
# staff there
# staff: 5
# doing there
# doing: 3
# which there
# which: 2
# close there
# close: 4
# about there
# about: 2
# could there
# could: 4
# sighs there
# sighs: 4
# place there
# place: 4
# larry there
# larry: 5
# gonna there
# gonna: 3
# never there
# never: 2
# pride there
# pride: 4
# spill there
# spill: 6
# alone there
# alone: 4
# touch there
# touch: 2
# start there
# start: 2
# stand there
# stand: 4
# wiles there
# wiles: 9
# loves there
# loves: 5
# later there
# later: 3
# would there
# would: 3
# would there
# would: 3
# where there
# where: 2
# boner there
# boner: 5
# jenna there
# jenna: 6
# madam there
# madam: 4
# wrong there
# wrong: 3
# still there
# still: 3
# leave there
# leave: 3
# maybe there
# maybe: 2
# stuff there
# stuff: 4
# mouth there
# mouth: 4
# again there
# again: 3
# sorry there
# sorry: 2
# being there
# being: 3
# going there
# going: 2
# their there
# their: 2
# these there
# these: 2
# whore there
# whore: 3
# great there
# great: 2
# bring there
# bring: 4
# water there
# water: 4
# could there
# could: 4
# gonna there
# gonna: 3
# ended there
# ended: 5

# %%
if __name__ == "__main__":
    main()
# Out:
# #1 Guess Word is: there
# Please enter a color string (5 letters)
# (b is gray; y is yellow; g is green): bbybb
# t there 0
# h there 1
# r there 3
# e there 4
# ['never', 'other', 'after', 'maybe', 'those', 'money', 'leave', 'years', 'hello', 'place', 'three', 'house', 'being', 'heard', 'alone', 'ready', 'haven', 'whole', 'while', 'since', 'heart', 'later', 'water', 'phone', 'death', 'under', 'times', 'comes', 'quite', 'close', 'makes', 'women', 'asked', 'means', 'honey', 'least', 'white', 'order', 'jesus', 'tried', 'alive', 'dance', 'power', 'uncle', 'quiet', 'write', 'taken', 'earth', 'drive', 'lives', 'tired', 'learn', 'loved', 'sense', 'takes', 'voice', 'state', 'seven', 'given', 'early', 'chief', 'horse', 'peace', 'movie', 'hotel', 'eight', 'worse', 'broke', 'miles', 'relax', 'table', 'paper', 'meant', 'enjoy', 'cover', 'force', 'teach', 'often', 'plane', 'lived', 'offer', 'smoke', 'agree', 'saved', 'river', 'weird', 'judge', 'wrote', 'cause', 'loves', 'liked', 'share', 'space', 'whose', 'peter', 'crime', 'gives', 'shoes', 'moved', 'likes', 'store', 'reach', 'rules', 'smile', 'henry', 'upset', 'begin', 'prove', 'price', 'devil', 'empty', 'above', 'named', 'blame', 'heavy', 'twice', 'waste', 'raise', 'taste', 'james', 'eddie', 'names', 'shame', 'stone', 'stage', 'beach', 'stole', 'knife', 'fired', 'angel', 'extra', 'large', 'level', 'heads', 'roger', 'tells', 'serve', 'began', 'spoke', 'grace', 'jerry', 'noise', 'exist', 'older', 'games', 'brave', 'nurse', 'naked', 'style', 'shake', 'enter', 'screw', 'loose', 'threw', 'whore', 'spare', 'thief', 'lines', 'lover', 'cares', 'trade', 'video', 'tears', 'super', 'mercy', 'scare', 'merry', 'ended', 'aware', 'grave', 'fixed', 'lower', 'below', 'model', 'shape', 'legal', 'faces', 'issue', 'bride', 'awake', 'based', 'alice', 'annie', 'kevin', 'image', 'marie', 'bones', 'owner', 'tower', 'pride', 'helen', 'beast', 'armed', 'fella', 'moves', 'hired', 'false', 'snake', 'drove', 'score', 'eaten', 'cases', 'chase', 'hated', 'julie', 'grade', 'aside', 'plate', 'bored', 'metal', 'penny', 'prime', 'tiger', 'loser', 'jones', 'chose', 'jenny', 'terms', 'notes', 'value', 'slave', 'shine', 'texas', 'cruel', 'terry', 'range', 'apple', 'prize', 'mixed', 'curse', 'noble', 'juice', 'kelly', 'hates', 'fever', 'karen', 'fetch', 'solve', 'title', 'leads', 'guide', 'bible', 'route', 'dozen', 'helps', 'media', 'bruce', 'exact', 'betty', 'tires', 'jesse', 'emily', 'tests', 'argue', 'vegas', 'anger', 'katie', 'gimme', 'trace', 'wayne', 'nerve', 'flies', 'alien', 'cents', 'files', 'sides', 'jokes', 'belly', 'cried', 'ellen', 'bells', 'homes', 'shore', 'mouse', 'wives', 'seats', 'waves', 'holes', 'rifle', 'hoped', 'fence', 'stake', 'novel', 'siren', 'demon', 'purse', 'hopes', 'equal', 'gates', 'begun', 'lewis', 'tries', 'teddy', 'beats', 'cable', 'eagle', 'tyler', 'beard', 'sauce', 'baker', 'cries', 'beans', 'roses', 'yells', 'frame', 'benny', 'boxes', 'jamie', 'cells', 'pearl', 'grief', 'alley', 'brief', 'angle', 'sends', 'raped', 'blade', 'upper', 'scale', 'alike', 'shave', 'delay', 'pedro', 'pages', 'bears', 'sales', 'allen', 'penis', 'cared', 'crane', 'egypt', 'janet', 'ashes', 'medal', 'goose', 'towel', 'slide', 'fires', 'faced', 'wendy', 'motel', 'romeo', 'denny', 'fried', 'liver', 'wears', 'pulse', 'taxes', 'dates', 'felix', 'vince', 'sarge', 'badge', 'derek', 'shove', 'poker', 'inner', 'kenny', 'entry', 'asses', 'booze', 'acted', 'owned', 'stare', 'flame', 'casey', 'feast', 'tense', 'safer', 'teams', 'blake', 'suite', 'hears', 'skies', 'korea', 'phase', 'sober', 'whale', 'spite', 'lemon', 'tapes', 'error', 'cease', 'fears', 'abuse', 'mikey', 'swore', 'blues', 'moore', 'elder', 'homer', 'types', 'reply', 'lenny', 'outer', 'loses', 'quote', 'added', 'lance', 'bench', 'ethan', 'edgar', 'adore', 'euros', 'deals', 'tribe', 'sakes', 'debts', 'depth', 'henri', 'chloe', 'cured', 'elvis', 'react', 'naive', 'wiped', 'slice', 'ellie', 'moses', 'meals', 'tales', 'megan', 'mines', 'swine', 'bloke', 'keith', 'reads', 'glove', 'rebel', 'diane', 'nicer', 'peggy', 'shane', 'petty', 'sells', 'votes', 'repay', 'belle', 'venus', 'weigh', 'dried', 'wells', 'bella', 'stove', 'ea ...
#
# #2 Guess Word is: never
# Please enter a color string (5 letters)
# (b is gray; y is yellow; g is green): ygbbb
# v never 2
# e never 3
# r never 4
# ['being', 'means', 'learn', 'sense', 'seven', 'meant', 'henry', 'begin', 'began', 'kevin', 'helen', 'penny', 'jenny', 'cents', 'fence', 'demon', 'begun', 'beans', 'benny', 'sends', 'penis', 'wendy', 'denny', 'kenny', 'tense', 'lemon', 'lenny', 'bench', 'henri', 'megan', 'venus', 'senor', 'veins', 'hence', 'jeans', 'reign', 'jenna', 'tenth', 'devon', 'genes', 'gents', 'melon', 'lenin', 'dense', 'genie', 'jeong', 'tends', 'tents', 'kenji', 'wench', 'denis', 'semen', 'recon', 'venom', 'renew', 'kenya', 'regan', 'leone', 'sedan', 'leung', 'penal', 'renee', 'verne', 'vents', 'venue', 'rents', 'reins', 'bends', 'genre', 'pence', 'felon', 'seine', 'yearn', 'heinz', 'tenor', 'denys', 'yeung', 'genoa', 'vegan', 'benjy', 'menus', 'henna', 'leona', 'lends', 'keane', 'resin', 'leans', 'reina', 'renny', 'verna', 'keanu', 'yemen', 'mende', 'meine', 'heron', 'levin', 'kenai', 'pecan', 'menem', 'rerun', 'bernd', 'texan', 'heini', 'reine', 'benin', 'bente', 'dents', 'jenks', 'seton', 'devin', 'lentz', 'leoni', 'peony', 'bengt', 'denim', 'feign', 'feint', 'xenon', 'heine', 'ferns', 'yentl', 'deign', 'lenox', 'wenke', 'renal', 'peons', 'xenia', 'berne', 'jeana', 'senna', 'jenni', 'deniz', 'renta', 'zenas', 'hearn', 'venal', 'behan', 'benes', 'genus', 'peron', 'renda', 'leong', 'meany', 'heman', 'deane', 'dente', 'hench', 'leann', 'lewin', 'denno', 'leant', 'venti', 'bevan', 'pense', 'reyna', 'benda', 'tenet', 'xenos', 'benet', 'terns', 'deion', 'renko', 'belen', 'deren', 'wentz', 'henke', 'kenzo', 'kenan', 'menil', 'benne', 'kerns', 'wenck', 'benno', 'serna', 'berns', 'denby', 'genet', 'zeman', 'bento', 'lento', 'renzi', 'zenda', 'benko', 'kenna', 'pepin', 'vesna', 'benja', 'fendi', 'penna', 'penta', 'mento', 'rengo', 'vento', 'benoy', 'heino', 'leben', 'lendl', 'tehan', 'tener', 'berna', 'fends', 'jenne', 'leana', 'melin', 'selin', 'beran', 'berni', 'deans', 'geron', 'kevan', 'leman', 'leino', 'menka', 'menon', 'pekin', 'wendt', 'benke', 'degan', 'denbo', 'genna', 'menlo', 'rench', 'teton', 'wends', 'jenin', 'lenzi', 'meson', 'pelon', 'zenon', 'herin', 'jeane', 'leven', 'merna', 'renne', 'tench', 'tenny', 'verno', 'bernt', 'deana', 'ledin', 'lenke', 'menke', 'belin', 'heyen', 'lebon', 'levan', 'mente', 'senko', 'aetna', 'dendy', 'fenno', 'helin', 'hendy', 'henie', 'herne', 'peine', 'pengo', 'perna', 'semon', 'zemin', 'zeyno', 'berny', 'beron', 'bevin', 'genco', 'hedin', 'henne', 'henze', 'lemen', 'menne', 'penza', 'regen', 'sendo', 'vendo', 'benel', 'cenci', 'deman', 'heins', 'kente', 'lenis', 'lenon', 'perno', 'retin', 'veron', 'wenge', 'wente', 'beine', 'bence', 'bendt', 'cerna', 'denki', 'denne', 'denwa', 'dewan', 'genis', 'gentz', 'geren', 'heiny', 'henly', 'hentz', 'keown', 'kerin', 'mehan', 'mench', 'menna', 'penry', 'rende', 'sevin', 'tejon', 'veyne', 'wenig', 'zenia']
#
# #3 Guess Word is: being
# Please enter a color string (5 letters)
# (b is gray; y is yellow; g is green): bgbyb
# b being 0
# i being 2
# g being 4
# ['learn', 'sense', 'seven', 'henry', 'begin', 'began', 'kevin', 'helen', 'cents', 'fence', 'demon', 'begun', 'sends', 'penis', 'wendy', 'tense', 'lemon', 'bench', 'henri', 'megan', 'venus', 'senor', 'hence', 'reign', 'tenth', 'devon', 'genes', 'gents', 'melon', 'lenin', 'dense', 'genie', 'tends', 'tents', 'kenji', 'wench', 'denis', 'semen', 'recon', 'venom', 'renew', 'kenya', 'regan', 'sedan', 'penal', 'renee', 'vents', 'venue', 'rents', 'bends', 'genre', 'pence', 'felon', 'yearn', 'tenor', 'denys', 'genoa', 'vegan', 'benjy', 'menus', 'lends', 'resin', 'yemen', 'mende', 'heron', 'levin', 'kenai', 'pecan', 'menem', 'rerun', 'texan', 'benin', 'bente', 'dents', 'jenks', 'seton', 'devin', 'lentz', 'bengt', 'denim', 'feign', 'xenon', 'yentl', 'deign', 'lenox', 'wenke', 'renal', 'xenia', 'deniz', 'renta', 'zenas', 'hearn', 'venal', 'behan', 'benes', 'genus', 'peron', 'renda', 'heman', 'dente', 'hench', 'lewin', 'venti', 'bevan', 'pense', 'benda', 'tenet', 'xenos', 'benet', 'deion', 'renko', 'belen', 'deren', 'wentz', 'henke', 'kenzo', 'kenan', 'menil', 'wenck', 'denby', 'genet', 'zeman', 'bento', 'lento', 'renzi', 'zenda', 'benko', 'pepin', 'benja', 'fendi', 'penta', 'mento', 'rengo', 'vento', 'benoy', 'leben', 'lendl', 'tehan', 'tener', 'fends', 'melin', 'selin', 'beran', 'geron', 'kevan', 'leman', 'menka', 'menon', 'pekin', 'wendt', 'benke', 'degan', 'denbo', 'menlo', 'rench', 'teton', 'wends', 'jenin', 'lenzi', 'meson', 'pelon', 'zenon', 'herin', 'leven', 'tench', 'ledin', 'lenke', 'menke', 'belin', 'heyen', 'lebon', 'levan', 'mente', 'senko', 'dendy', 'helin', 'hendy', 'henie', 'pengo', 'semon', 'zemin', 'beron', 'bevin', 'genco', 'hedin', 'henze', 'lemen', 'penza', 'regen', 'sendo', 'vendo', 'benel', 'cenci', 'deman', 'kente', 'lenis', 'lenon', 'retin', 'veron', 'wenge', 'wente', 'bence', 'bendt', 'denki', 'denwa', 'dewan', 'genis', 'gentz', 'geren', 'henly', 'hentz', 'keown', 'kerin', 'mehan', 'mench', 'penry', 'rende', 'sevin', 'tejon', 'wenig', 'zenia']
#
# #4 Guess Word is: learn
# Please enter a color string (5 letters)
# (b is gray; y is yellow; g is green): ggbbg
# a learn 2
# r learn 3
# ['learn', 'lemon', 'lenin', 'levin', 'lewin', 'leben', 'leman', 'leven', 'ledin', 'lebon', 'levan', 'lemen', 'lenon']
#
# #5 Guess Word is: learn
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-972361fa1b80> in <module>
#       1 if __name__ == "__main__":
# ----> 2     main()
#
# <ipython-input-14-836125c00f96> in main()
#      58     while True:
#      59         guess_times += 1
# ---> 60         input_color = input("Please enter a color string (5 letters) \n(b is gray; y is yellow; g is green): ")
#      61         if input_color == 'no':
#      62             all_words, input_word = pass_word(all_words)
#
# ~/miniconda3/envs/py3/lib/python3.9/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     846                 "raw_input was called, but this frontend does not support input requests."
#     847             )
# --> 848         return self._input_request(str(prompt),
#     849             self._parent_ident,
#     850             self._parent_header,
#
# ~/miniconda3/envs/py3/lib/python3.9/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     890             except KeyboardInterrupt:
#     891                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 892                 raise KeyboardInterrupt("Interrupted by user") from None
#     893             except Exception as e:
#     894                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
bbybb
ygbbb
bgbyb
ggbbg
